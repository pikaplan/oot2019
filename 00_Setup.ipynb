# %% [markdown]
# # Object Oriented Tensorflow Tutorial
#
# Created and presented by [Pantelis I. Kaplanoglou](http://pantelis.me). The instructions here will help you setup the workspace for the tutorial in your own Google Colab environment.
#
# <img src="https://miro.medium.com/max/1200/1*uyQ61XHkTY2qHhovclaLIQ.png" width="500" border="1"/>

# %% [markdown]
# ## Sign-In and copy to drive
# Once you have this python notepook opened, sign in with your Google account. Use the menu command `File -> Save a copy in Drive` to copy this file into your private workspace. This will also create a folder `Colab Notebooks` in your Google Drive.

# %% [markdown]
# ## Mounting Google Drive
# Running the folllowing source code cell from your own Collab workspace, will mount your Google Drive storage to the current runtime that hosts the `.ipynb` file. Follow the URL to authorize Google Filestream into accessing your Drive. You will get an authorization code, copy-paste it here and press enter in order to complete the mounting process.

# %%
from google.colab import drive

drive.mount('/content/gdrive/')

# %% [markdown]
# ## Cloning from GitHub
#
# Te contents of the tutorial are cloned from GitHub into your Google Drive path `Colab Notebooks/OOT2019`

# %%
# !mkdir "/content/gdrive/My Drive/Colab Notebooks/OOT2019"
# !git clone https://github.com/pikaplan/oot2019 "/content/gdrive/My Drive/Colab Notebooks/OOT2019"

# %% [markdown]
# ## Tutorial Contents
# Use the menu command `File -> Locate` in Drive to open the contents of the tutorial or run the source code bellow to get a quick directory listing.

# %%
import os

TUTORIAL_BASE_FOLDER = "/content/gdrive/My Drive/Colab Notebooks/OOT2019"

for sFileName in sorted(os.listdir(TUTORIAL_BASE_FOLDER)):
  print(sFileName)
